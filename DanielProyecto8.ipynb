# %% [markdown]
# <a href="https://colab.research.google.com/github/ulloadl/Lab22Junio/blob/main/DanielProyecto8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Laboratorio guiado #8 :***

# %% [markdown]
# ***Estudiante: Daniel Leonardo Ulloa Rojas***

# %% [markdown]
# ***Paso #1 ✅***

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %% [markdown]
# ***Paso #2 - Gráfico de Lineas ✅***

# %%
import matplotlib.pyplot as plt
 
x  = [1, 2, 3, 4, 5, 6, 7, 8, 9]
y1 = [1, 3, 5, 3, 1, 3, 5, 3, 1]
y2 = [2, 4, 6, 4, 2, 4, 6, 4, 2]
plt.plot(x, y1, label="line I")
plt.plot(x, y2, label="line H")
plt.plot()

plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Line Graph Example")
plt.legend()
plt.show()

# %% [markdown]
# ***Paso #3 - Gráfico de barras ✅***

# %%
import matplotlib.pyplot as plt

x1 = [1, 3, 4, 5, 6, 7, 9]
y1 = [4, 7, 2, 4, 7, 8, 3]

x2 = [2, 4, 6, 8, 10]
y2 = [5, 6, 2, 6, 2]

plt.show()

plt.bar(x1, y1, label="Cyan", color='c')
plt.bar(x2, y2, label="Green", color='g')
plt.plot()

plt.xlabel("bar number")
plt.ylabel("bar height")
plt.title("Bar Chart Example")
plt.legend()
plt.show()

# %% [markdown]
# ***Paso #4 - Gráficos de Histogramas ✅***

# %%
import matplotlib.pyplot as plt
import numpy as np

n = np.random.randn(1000)

m = [m for m in range(len(n))]
plt.bar(m, n)
plt.title("Datos de calificaciones")
plt.show()

plt.hist(n, bins=20)
plt.title("Histograma")
plt.show()

# %% [markdown]
# ***Paso #5 - Gráficos con Marcas ✅***

# %%
import matplotlib.pyplot as plt

x1 = [2, 3, 4]
y1 = [5, 5, 5]

x2 = [1, 2, 3, 4, 5]
y2 = [2, 3, 2, 3, 4]
y3 = [6, 8, 7, 8, 7]

plt.scatter(x1, y1, marker="d", color='b')
plt.scatter(x2, y2, marker="*", color='r')
plt.scatter(x2, y3, marker="x", color='m')
plt.title('Scatter Plot Example')
plt.show()

# %% [markdown]
# ***Paso #6 - Mapas de Color ✅***

# %%
import numpy as np; np.random.seed(0)

import seaborn as sns; sns.set_theme()

uniform_data = np.random.rand(100, 160)

ax = sns.heatmap(uniform_data)
